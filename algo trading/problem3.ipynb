# %%
import pandas as pd
import numpy as np

C = pd.read_csv('c.csv',index_col = 0 )


stock_data = pd.read_csv('stock_data.csv',header=2)
stock_data[stock_data['Group']==4]
# Out:
#     Group Symbol   Price       ADV  Volatility  LnMktCap  EstReturn %
# 75      4    CAT   78.63   5224000      0.2017     24.49         0.14
# 76      4     CB  124.33   1223000      0.2069     24.12         0.10
# 77      4    CBG   37.97   2061000      0.2103     23.24         0.14
# 78      4    CBS   53.28   6561000      0.2214     23.90         0.12
# 79      4    CCE   50.80   2210000      0.2038     23.17         0.10
# 80      4    CCI   81.91   2550000      0.1691     24.09         0.08
# 81      4    CCL   52.99   4036000      0.2240     24.43         0.09
# 82      4   CELG  131.25   5468000      0.2824     25.21         0.17
# 83      4   CERN   71.72   1652000      0.2176     23.73         0.14
# 84      4     CF   58.89   3777000      0.2457     23.09         0.12
# 85      4    CHK    8.66  13378000      0.4070     22.02         0.21
# 86      4   CHRW   69.75   1680000      0.2149     23.01         0.15
# 87      4     CI  144.06   1834000      0.2384     24.27         0.14
# 88      4   CINF   55.21    566000      0.1412     23.03         0.06
# 89      4     CL   68.02   3051000      0.1392     24.82         0.07
# 90      4    CLX  111.94   1027000      0.1398     23.51         0.10
# 91      4    CMA   47.43   1617000      0.2155     22.83         0.09
# 92      4  CMCSA   62.41  13844000      0.1829     25.74         0.08
# 93      4    CME   95.52   1635000      0.1867     24.21         0.14
# 94      4    CMG  742.23    463000      0.2700     23.61         0.15
# 95      4    CMI  128.54   1495000      0.2062     23.59         0.10
# 96      4    CMS   33.97   2609000      0.1667     23.00         0.08
# 97      4    CNP   19.09   3888000      0.1839     22.72         0.07
# 98      4    CNX   16.51   2941000      0.3239     21.27         0.14
# 99      4    COF   80.90   2915000      0.1947     24.48         0.14

# %%
C
# Out:
#             CAT        CB       CBG       CBS       CCE       CCI       CCL  \
# CAT    0.027300 -0.000151 -0.000174  0.000286 -0.001080 -0.001031 -0.002315
# CB    -0.000151  0.035476  0.000095 -0.000474  0.000865  0.001094  0.000975
# CBG   -0.000174  0.000095  0.028920 -0.000053  0.000120  0.000130  0.000205
# CBS    0.000286 -0.000474 -0.000053  0.029493 -0.000388 -0.000460 -0.000537
# CCE   -0.001080  0.000865  0.000120 -0.000388  0.028074  0.001053  0.001484
# CCI   -0.001031  0.001094  0.000130 -0.000460  0.001053  0.024501  0.001584
# CCL   -0.002315  0.000975  0.000205 -0.000537  0.001484  0.001584  0.036332
# CELG  -0.006776  0.001045  0.000489 -0.000961  0.003268  0.003251  0.006582
# CERN  -0.001414 -0.000737  0.000046  0.000118  0.000114 -0.000055  0.000778
# CF    -0.000389  0.000484  0.000058 -0.000203  0.000436  0.000507  0.000636
# CHK    0.011447 -0.004137 -0.000988  0.002443 -0.006915 -0.007290 -0.012571
# CHRW   0.000280 -0.000578 -0.000053  0.000220 -0.000452 -0.000543 -0.000604
# CI    -0.000251  0.000372  0.000046 -0.000157  0.000312  0.000367  0.000440
# CINF   0.001367 -0.000017 -0.000087  0.000129 -0.000544 -0.000507 -0.001207
# CL    -0.000767  0.001558  0.000140 -0.000590  0.001227  0.001474  0.001645
# CLX   -0.000909  0.001329  0.000140 -0.000532  0.001142  0.001344  0.001619
# CMA    0.006838 -0.003367 -0.000630  0.001743 -0.004674 -0.005056 -0.008085
# CMCSA -0.000108  0.000831  0.000058 -0.000290  0.000535  0.000674  0.000610
# CME    0.000559  0.000008 -0.000031  0.000043 -0.000217 -0.000200 -0.000489
# CMG   -0.001683 -0.001136  0.000046  0.000220 -0.000023 -0.000270  0.000756
# CMI    0.001483 -0.000418 -0.000122  0.000278 -0.000825 -0.000853 -0.001554
# CMS    0.000095  0.001474  0.000084 -0.000488  0.000837  0.001094  0.000833
# CNP    0.001460  0.001239 -0.000026 -0.000274  0.000173  0.000432 -0.000495
# CNX    0.006352 -0.002565 -0.000568  0.001450 -0.003994 -0.004247 -0.007138
# COF    0.002127 -0.000890 -0.000188  0.000491 -0.001360 -0.001451 -0.002416
#
#            CELG      CERN        CF    ...          CLX       CMA  \
# CAT   -0.006776 -0.001414 -0.000389    ...    -0.000909  0.006838
# CB     0.001045 -0.000737  0.000484    ...     0.001329 -0.003367
# CBG    0.000489  0.000046  0.000058    ...     0.000140 -0.000630
# CBS   -0.000961  0.000118 -0.000203    ...    -0.000532  0.001743
# CCE    0.003268  0.000114  0.000436    ...     0.001142 -0.004674
# CCI    0.003251 -0.000055  0.000507    ...     0.001344 -0.005056
# CCL    0.006582  0.000778  0.000636    ...     0.001619 -0.008085
# CELG   0.062722  0.003374  0.001247    ...     0.003031 -0.019686
# CERN   0.003374  0.029569 -0.000063    ...    -0.000269 -0.002001
# CF     0.001247 -0.000063  0.050799    ...     0.000573 -0.002041
# CHK   -0.032154 -0.004262 -0.002924    ...    -0.007354  0.038382
# CHRW  -0.001016  0.000185 -0.000233    ...    -0.000630  0.001987
# CI     0.000815 -0.000076  0.000165    ...     0.000424 -0.001419
# CINF  -0.003617 -0.000799 -0.000186    ...    -0.000429  0.003544
# CL     0.002785 -0.000492  0.000629    ...     0.001703 -0.005410
# CLX    0.003031 -0.000269  0.000573    ...     0.017549 -0.005242
# CMA   -0.019686 -0.002001 -0.002041    ...    -0.005242  0.046986
# CMCSA  0.000681 -0.000441  0.000297    ...     0.000816 -0.002098
# CME   -0.001484 -0.000335 -0.000068    ...    -0.000163  0.001437
# CMG    0.003870  0.001686 -0.000158    ...    -0.000566 -0.001779
# CMI   -0.004105 -0.000624 -0.000339    ...    -0.000841  0.004706
# CMS    0.000456 -0.000951  0.000489    ...     0.001362 -0.002994
# CNP   -0.003227 -0.001617  0.000223    ...     0.000732  0.000972
# CNX   -0.017960 -0.002202 -0.001716    ...    -0.004334  0.021871
# COF   -0.006045 -0.000718 -0.000582    ...    -0.001482  0.007417
#
#               CMCSA           CME       CMG       CMI       CMS       CNP  \
# CAT   -1.075337e-04  5.585484e-04 -0.001683  0.001483  0.000095  0.001460
# CB     8.307922e-04  7.635420e-06 -0.001136 -0.000418  0.001474  0.001239
# CBG    5.798129e-05 -3.083355e-05  0.000046 -0.000122  0.000084 -0.000026
# CBS   -2.899680e-04  4.308062e-05  0.000220  0.000278 -0.000488 -0.000274
# CCE    5.345269e-04 -2.169065e-04 -0.000023 -0.000825  0.000837  0.000173
# CCI    6.743389e-04 -2.003142e-04 -0.000270 -0.000853  0.001094  0.000432
# CCL    6.096900e-04 -4.893494e-04  0.000756 -0.001554  0.000833 -0.000495
# CELG   6.807435e-04 -1.483893e-03  0.003870 -0.004105  0.000456 -0.003227
# CERN  -4.407569e-04 -3.346994e-04  0.001686 -0.000624 -0.000951 -0.001617
# CF     2.969237e-04 -6.837729e-05 -0.000158 -0.000339  0.000489  0.000223
# CHK   -2.594054e-03  2.419278e-03 -0.004396  0.007515 -0.003360  0.003155
# CHRW  -3.541753e-04  4.584012e-05  0.000330  0.000300 -0.000604 -0.000392
# CI     2.268415e-04 -3.614395e-05 -0.000147 -0.000234  0.000378  0.000191
# CINF  -1.906147e-05  3.044167e-04 -0.000960  0.000781  0.000120  0.000843
# CL     9.561023e-04 -1.306376e-04 -0.000887 -0.000816  0.001630  0.001058
# CLX    8.161819e-04 -1.625389e-04 -0.000566 -0.000841  0.001362  0.000732
# CMA   -2.098371e-03  1.436619e-03 -0.001779  0.004706 -0.002994  0.000972
# CMCSA  2.058720e-02  4.054883e-07 -0.000684 -0.000264  0.000899  0.000749
# CME    4.054883e-07  2.469170e-02 -0.000398  0.000315  0.000063  0.000350
# CMG   -6.835413e-04 -3.980489e-04  0.063190 -0.000680 -0.001418 -0.002194
# CMI   -2.637246e-04  3.153200e-04 -0.000680  0.023566 -0.000305  0.000528
# CMS    8.986147e-04  6.347511e-05 -0.001418 -0.000305  0.024438  0.001510
# CNP    7.485357e-04  3.501237e-04 -0.002194  0.000528  0.001510  0.025986
# CNX   -1.602942e-03  1.330705e-03 -0.002199  0.004236 -0.002158  0.001493
# COF   -5.565185e-04  4.501839e-04 -0.000700  0.001426 -0.000758  0.000460
#
#             CNX       COF
# CAT    0.006352  0.002127
# CB    -0.002565 -0.000890
# CBG   -0.000568 -0.000188
# CBS    0.001450  0.000491
# CCE   -0.003994 -0.001360
# CCI   -0.004247 -0.001451
# CCL   -0.007138 -0.002416
# CELG  -0.017960 -0.006045
# CERN  -0.002202 -0.000718
# CF    -0.001716 -0.000582
# CHK    0.034174  0.011535
# CHRW   0.001607  0.000552
# CI    -0.001201 -0.000402
# CINF   0.003311  0.001110
# CL    -0.004367 -0.001505
# CLX   -0.004334 -0.001482
# CMA    0.021871  0.007417
# CMCSA -0.001603 -0.000557
# CME    0.001331  0.000450
# CMG   -0.002199 -0.000700
# CMI    0.004236  0.001426
# CMS   -0.002158 -0.000758
# CNP    0.001493  0.000460
# CNX    0.103741  0.006549
# COF    0.006549  0.024182
#
# [25 rows x 25 columns]

# %% [markdown]
# # qp solver funtion

# %%
from cvxopt import matrix, solvers


def optimal_port(expected_return):
    
    solvers.options['show_progress'] = False      #disable progress
    

    symbol = list(C.index)
    C_s = C.as_matrix()             #convert to matrix
    
    data = stock_data[stock_data['Symbol'].isin(symbol)]      #select stock data based on symbol
    #print data
    ret_T = np.matrix(data['EstReturn %'])                     #get returns 
    #ret_T
    
    n = len(C_s)
    
    # w'Cw minimization using qp
    
    Q = matrix(C_s)                                         # covariance matrix
    p = matrix(np.full((n, 1), 0.))                         # return matrix, 0 here because returns are specfied outside,here only w'Cw
    G = matrix(np.r_[np.eye(n),-np.eye(n)])                 # inequality equation leftside
    h = matrix(np.r_[np.full((n, 1), 0.25),np.full((n, 1), -0.005)])  # inequality equation lrightside
    A = matrix(np.r_[np.full((1, n), 1.0),ret_T] ,(2,n))              # equality equation leftside
    b = matrix([1.0,expected_return],(2,1))                           # equality equation rightside
    
    sol=solvers.qp(Q, p, G, h, A, b)
    
    std =  np.sqrt(np.dot(np.dot(np.array(sol['x']).T,C_s),np.array(sol['x'])))  # std = sqrt(w'Cw)
    returns = np.sum(np.full((n, 1), expected_return)*np.array(sol['x']))        # returns = sumproduct(w,R)
    #print returns
    #print std.shape
    return np.r_[np.array(sol['x']),std,np.array([[returns]])]                  # return w,std,return which is [n+2,1] matrix, n is the len(C)

#expected_return = 0.13
#print expected_return
#optimal_port(expected_return)

# %% [markdown]
# # protfolio with different expected return

# %%
weights = np.zeros([len(C)+2,1])            #initial an empty array
expected_return = [0.165,0.16,0.155,0.15,0.145,0.14,0.135,0.13,0.125,0.12,0.115,0.11,0.105,0.10,0.09,0.08]


for j in expected_return:
    weights = np.c_[weights,optimal_port(j)]
    
weights = np.delete(weights, 0, 1)
weights = pd.DataFrame(weights.T ,columns=['w'+ str(i) for i in xrange(1,len(C)+1)]+['std','ret'],index=['portfolio'+ str(i) for i in xrange(1,len(expected_return)+1)])
weights
# Out:
#                    w1        w2        w3        w4        w5        w6  \
# portfolio1   0.005001  0.005000  0.020524  0.005000  0.005000  0.005000
# portfolio2   0.034368  0.005000  0.052650  0.005000  0.005000  0.005000
# portfolio3   0.065425  0.005000  0.065128  0.005000  0.005000  0.005000
# portfolio4   0.085703  0.005001  0.081706  0.005009  0.005001  0.005000
# portfolio5   0.097556  0.005000  0.090997  0.025553  0.005000  0.005000
# portfolio6   0.092848  0.016188  0.085664  0.043813  0.018895  0.005000
# portfolio7   0.084367  0.026141  0.077298  0.048484  0.032525  0.007351
# portfolio8   0.075780  0.028309  0.069503  0.048496  0.036448  0.019331
# portfolio9   0.066798  0.028641  0.062422  0.046990  0.038107  0.026714
# portfolio10  0.058449  0.028120  0.056046  0.044945  0.038558  0.031467
# portfolio11  0.050103  0.027596  0.049673  0.042899  0.039004  0.036209
# portfolio12  0.041756  0.027071  0.043300  0.040852  0.039450  0.040951
# portfolio13  0.032890  0.026548  0.036696  0.038669  0.039981  0.045937
# portfolio14  0.022840  0.026023  0.029571  0.036169  0.040700  0.051467
# portfolio15  0.005036  0.024846  0.014770  0.030788  0.042135  0.062779
# portfolio16  0.005000  0.011358  0.005000  0.005002  0.029513  0.078457
#
#                    w7        w8        w9       w10  ...         w18  \
# portfolio1   0.005000  0.250000  0.016321  0.005000  ...    0.005000
# portfolio2   0.005000  0.250000  0.046982  0.005000  ...    0.005000
# portfolio3   0.005000  0.233165  0.057853  0.005000  ...    0.005000
# portfolio4   0.005000  0.178847  0.076720  0.005019  ...    0.005000
# portfolio5   0.005000  0.131189  0.087913  0.020380  ...    0.005000
# portfolio6   0.005024  0.103351  0.084611  0.029311  ...    0.005000
# portfolio7   0.017250  0.084186  0.077926  0.030599  ...    0.006031
# portfolio8   0.023057  0.071432  0.071878  0.029417  ...    0.019795
# portfolio9   0.026684  0.062697  0.066521  0.027785  ...    0.028497
# portfolio10  0.028949  0.055793  0.061655  0.026028  ...    0.033983
# portfolio11  0.031210  0.048896  0.056791  0.024270  ...    0.039456
# portfolio12  0.033470  0.041999  0.051927  0.022512  ...    0.044930
# portfolio13  0.035935  0.035169  0.046938  0.020700  ...    0.050584
# portfolio14  0.038860  0.028495  0.041662  0.018767  ...    0.056637
# portfolio15  0.044951  0.015176  0.030751  0.014718  ...    0.068854
# portfolio16  0.047787  0.005000  0.005000  0.005000  ...    0.085479
#
#                   w19       w20       w21       w22       w23       w24  \
# portfolio1   0.010413  0.130438  0.005000  0.005000  0.005000  0.005000
# portfolio2   0.054141  0.084448  0.005000  0.005000  0.005000  0.005000
# portfolio3   0.073420  0.066606  0.005000  0.005000  0.005000  0.005960
# portfolio4   0.093223  0.060399  0.005001  0.005000  0.005000  0.013353
# portfolio5   0.104473  0.053389  0.005000  0.005000  0.005000  0.018741
# portfolio6   0.098682  0.047124  0.007167  0.005000  0.005000  0.020011
# portfolio7   0.089252  0.041714  0.028131  0.007078  0.005005  0.019810
# portfolio8   0.080277  0.037775  0.036351  0.018122  0.005391  0.019074
# portfolio9   0.071794  0.034516  0.039839  0.024332  0.011655  0.017322
# portfolio10  0.064081  0.031679  0.041251  0.027964  0.017094  0.015452
# portfolio11  0.056371  0.028844  0.042655  0.031586  0.022526  0.013581
# portfolio12  0.048661  0.026009  0.044059  0.035208  0.027959  0.011710
# portfolio13  0.040613  0.023100  0.045320  0.038959  0.033460  0.009617
# portfolio14  0.031795  0.020020  0.046246  0.042997  0.039106  0.007289
# portfolio15  0.013392  0.013665  0.047663  0.051115  0.050334  0.005002
# portfolio16  0.005000  0.005000  0.031394  0.061961  0.073444  0.005000
#
#                   w25       std    ret
# portfolio1   0.005001  0.120782  0.165
# portfolio2   0.024729  0.098155  0.160
# portfolio3   0.061877  0.080245  0.155
# portfolio4   0.086940  0.065944  0.150
# portfolio5   0.102313  0.056127  0.145
# portfolio6   0.099667  0.049896  0.140
# portfolio7   0.092425  0.045196  0.135
# portfolio8   0.084929  0.041550  0.130
# portfolio9   0.076631  0.038600  0.125
# portfolio10  0.068752  0.036240  0.120
# portfolio11  0.060874  0.034505  0.115
# portfolio12  0.052997  0.033493  0.110
# portfolio13  0.044588  0.033274  0.105
# portfolio14  0.034969  0.033922  0.100
# portfolio15  0.014602  0.037654  0.090
# portfolio16  0.005000  0.044954  0.080
#
# [16 rows x 27 columns]

# %% [markdown]
# # efficient frontier

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(weights['std'],weights['ret'],'y-o')

# %% [markdown]
# # problem 3.2
# # according to the chart before
# # expected return = 10
# # std = 0.033922

# %% [markdown]
# # For a  $100 Million Dollar Portfolio

# %%
capital = 100*10**6
w = np.array([weights.loc['portfolio14'][0:25]]).T
price = np.array([stock_data[stock_data['Group']==4]['Price']]).T
shares = w*capital / price

ADV = np.array([stock_data[stock_data['Group']==4]['ADV']],dtype='f8').T
size  = shares / ADV                                                     # size(%ADV) 
time = 1                                                                 # trade time % of day. relation to POV = size*(1-POV)/POV
POV = shares/(shares+time*ADV)                                           #shares/VOL = shares / (shares+time*ADV)
volatility = np.array([stock_data[stock_data['Group']==4]['Volatility']],dtype='f8').T

x = np.array(np.c_[size, volatility, POV])

# %%
coeffs = [698.74940594355189, 0.3429159597976898, 0.55893058943625173, 0.74906715225239062, 0.97462393173698603]     #from problem 2
def MI_model(x):
    "market impact function"
    
    s = np.array(x[0])          #size
    v = np.array(x[1])          #volatility
    P = np.array(x[2])          #POV

    return coeffs[0]*(s**coeffs[1])*(v **coeffs[2]) * (coeffs[4]*(P **coeffs[3])+ (1-coeffs[4]))

MI_model(x[1])
# Out:
# 5.1031557589294492

# %%
mi = []
for i in xrange(len(x)):
    mi.append(MI_model(x[i]))
    
stocks = stock_data[stock_data['Group']==4] 
stocks.loc[:,'market_impact(bp)'] = mi
stocks.loc[:,'market_impact(decimal)'] = np.array(mi)/10000
stocks.loc[:,'market_impact(dollar)'] = np.array([mi]).T/10000*w*capital
stocks.loc[:,'net_return'] = stocks.loc[:,'EstReturn %']-stocks.loc[:,'market_impact(decimal)']*100
stocks
# Out:
# C:\Users\bjd\Anaconda3\envs\py2.7\lib\site-packages\pandas\core\indexing.py:297: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\bjd\Anaconda3\envs\py2.7\lib\site-packages\pandas\core\indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#     Group Symbol   Price       ADV  Volatility  LnMktCap  EstReturn %  \
# 75      4    CAT   78.63   5224000      0.2017     24.49         0.14
# 76      4     CB  124.33   1223000      0.2069     24.12         0.10
# 77      4    CBG   37.97   2061000      0.2103     23.24         0.14
# 78      4    CBS   53.28   6561000      0.2214     23.90         0.12
# 79      4    CCE   50.80   2210000      0.2038     23.17         0.10
# 80      4    CCI   81.91   2550000      0.1691     24.09         0.08
# 81      4    CCL   52.99   4036000      0.2240     24.43         0.09
# 82      4   CELG  131.25   5468000      0.2824     25.21         0.17
# 83      4   CERN   71.72   1652000      0.2176     23.73         0.14
# 84      4     CF   58.89   3777000      0.2457     23.09         0.12
# 85      4    CHK    8.66  13378000      0.4070     22.02         0.21
# 86      4   CHRW   69.75   1680000      0.2149     23.01         0.15
# 87      4     CI  144.06   1834000      0.2384     24.27         0.14
# 88      4   CINF   55.21    566000      0.1412     23.03         0.06
# 89      4     CL   68.02   3051000      0.1392     24.82         0.07
# 90      4    CLX  111.94   1027000      0.1398     23.51         0.10
# 91      4    CMA   47.43   1617000      0.2155     22.83         0.09
# 92      4  CMCSA   62.41  13844000      0.1829     25.74         0.08
# 93      4    CME   95.52   1635000      0.1867     24.21         0.14
# 94      4    CMG  742.23    463000      0.2700     23.61         0.15
# 95      4    CMI  128.54   1495000      0.2062     23.59         0.10
# 96      4    CMS   33.97   2609000      0.1667     23.00         0.08
# 97      4    CNP   19.09   3888000      0.1839     22.72         0.07
# 98      4    CNX   16.51   2941000      0.3239     21.27         0.14
# 99      4    COF   80.90   2915000      0.1947     24.48         0.14
#
#     market_impact(bp)  market_impact(decimal)  market_impact(dollar)  \
# 75           2.177419                0.000218             497.326941
# 76           5.103156                0.000510            1328.014941
# 77          10.158466                0.001016            3003.958330
# 78           3.569185                0.000357            1290.944139
# 79           9.619436                0.000962            3915.130800
# 80           6.184682                0.000618            3183.091188
# 81           5.603130                0.000560            2177.381501
# 82           2.113165                0.000211             602.151834
# 83           9.711299                0.000971            4045.957628
# 84           3.253035                0.000325             610.510186
# 85           2.733027                0.000273             136.725640
# 86           6.223850                0.000622            1546.016351
# 87           2.686921                0.000269             468.539808
# 88          74.614542                0.007461          101509.863318
# 89           9.449616                0.000945            8836.218910
# 90          11.110004                0.001111            6856.590376
# 91          16.240654                0.001624            7768.592931
# 92           2.306072                0.000231            1306.089434
# 93           5.561548                0.000556            1768.284634
# 94           2.644564                0.000264             529.438325
# 95           6.771735                0.000677            3131.687369
# 96          11.176623                0.001118            4805.664221
# 97          12.730105                0.001273            4978.206799
# 98           5.896179                0.000590             429.748871
# 99           4.393129                0.000439            1536.221347
#
#     net_return
# 75    0.118226
# 76    0.048968
# 77    0.038415
# 78    0.084308
# 79    0.003806
# 80    0.018153
# 81    0.033969
# 82    0.148868
# 83    0.042887
# 84    0.087470
# 85    0.182670
# 86    0.087762
# 87    0.113131
# 88   -0.686145
# 89   -0.024496
# 90   -0.011100
# 91   -0.072407
# 92    0.056939
# 93    0.084385
# 94    0.123554
# 95    0.032283
# 96   -0.031766
# 97   -0.057301
# 98    0.081038
# 99    0.096069

# %%
# expected Net Return
e_n_return  = np.sum(stocks.loc[:,'net_return'])
e_n_return
# Out:
# 0.5996845957420169

# %% [markdown]
# # For a $500 Million Dollar Portfolio:

# %%
capital = 500*10**6
w = np.array([weights.loc['portfolio14'][0:25]]).T
price = np.array([stock_data[stock_data['Group']==4]['Price']]).T
shares = w*capital / price

ADV = np.array([stock_data[stock_data['Group']==4]['ADV']],dtype='f8').T
size  = shares / ADV                                                     # size(%ADV) 
time = 1                                                                 # trade time % of day. relation to POV = size*(1-POV)/POV
POV = shares/(shares+time*ADV)                                           #shares/VOL = shares / (shares+time*ADV)
volatility = np.array([stock_data[stock_data['Group']==4]['Volatility']],dtype='f8').T

x = np.array(np.c_[size, volatility, POV])
mi = []
for i in xrange(len(x)):
    mi.append(MI_model(x[i]))
    
stocks = stock_data[stock_data['Group']==4] 
stocks.loc[:,'market_impact(bp)'] = mi
stocks.loc[:,'market_impact(decimal)'] = np.array(mi)/10000

stocks.loc[:,'market_impact(dollar)'] = np.array([mi]).T/10000*w*capital
stocks.loc[:,'net_return'] = stocks.loc[:,'EstReturn %']-stocks.loc[:,'market_impact(decimal)']*100
#stocks
size
# Out:
# array([[ 0.02780216],
#        [ 0.08557201],
#        [ 0.18893708],
#        [ 0.05173378],
#        [ 0.18126363],
#        [ 0.12320395],
#        [ 0.09085079],
#        [ 0.01985248],
#        [ 0.17581814],
#        [ 0.04218768],
#        [ 0.02159071],
#        [ 0.10599161],
#        [ 0.03300037],
#        [ 2.17681034],
#        [ 0.2252908 ],
#        [ 0.26841591],
#        [ 0.31184998],
#        [ 0.03277588],
#        [ 0.10179219],
#        [ 0.02912808],
#        [ 0.12032863],
#        [ 0.24257341],
#        [ 0.2634382 ],
#        [ 0.07505368],
#        [ 0.07414174]])

# %%
e_n_return  = np.sum(stocks.loc[:,'net_return'])
e_n_return
# Out:
# -6.066884099108871

# %% [markdown]
# # problem 3.3
