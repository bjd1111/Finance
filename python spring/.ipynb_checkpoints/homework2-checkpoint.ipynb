# %% [markdown]
# # get stock data from web

# %%
# -*- coding: utf-8 -*-



import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline


start = datetime.date(2000,1,1)
end = datetime.date(2007,1,1)


import pandas_datareader.data as web

import datetime

start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2013, 1, 27)


spy = web.DataReader("SPY", 'yahoo', start, end)

xom = web.DataReader("XOM", 'yahoo', start, end)
gs = web.DataReader("GS", 'yahoo', start, end)
bhp = web.DataReader("BHP", 'yahoo', start, end)
de = web.DataReader("DE", 'yahoo', start, end)
fe = web.DataReader("FE", 'yahoo', start, end)
goog = web.DataReader("GOOG", 'yahoo', start, end)
vz = web.DataReader("VZ", 'yahoo', start, end)
wmt = web.DataReader("WMT", 'yahoo', start, end)
ko = web.DataReader("KO", 'yahoo', start, end)
jnj = web.DataReader("JNJ", 'yahoo', start, end)


spy_close = spy['Adj Close'] 

xom_close = xom['Adj Close'] 
gs_close = gs['Adj Close'] 
bhp_close = bhp['Adj Close'] 
de_close = de['Adj Close']
fe_close = fe['Adj Close']
goog_close = goog['Adj Close'] 
vz_close = vz['Adj Close'] 
wmt_close = wmt['Adj Close']
ko_close = ko['Adj Close']
jnj_close = jnj['Adj Close']




symbols = ['XOM','GS', 'BHP','DE','FE', 'GOOG','VZ', 'WMT','KO','JNJ']
noa = len(symbols)


data = pd.DataFrame({
    'xom_close' :xom_close,
    'gs_close':gs_close, 
    'bhp_close':bhp_close, 
    'de_close':de_close, 
    'fe_close':fe_close, 
    'goog_close':goog_close, 
    'vz_close':vz_close,
    'wmt_close':wmt_close,
    'ko_close':ko_close, 
    'jnj_close':jnj_close
})


log_returns=np.log(data/data.shift(1))

# Plotting the Price series

(data / data.ix[0] * 100).plot(figsize=(8, 5))

rets = np.log(data / data.shift(1))

# %%
#The mean and covariance matrix for the assets
rets.mean() * 252
rets.cov() * 252
# Out:
#             bhp_close  de_close  fe_close  goog_close  gs_close  jnj_close  \
# bhp_close    0.111807  0.070351  0.029943    0.044795  0.067048   0.027679
# de_close     0.070351  0.085156  0.022965    0.038539  0.051878   0.021855
# fe_close     0.029943  0.022965  0.038714    0.016841  0.021576   0.012975
# goog_close   0.044795  0.038539  0.016841    0.072218  0.038167   0.014665
# gs_close     0.067048  0.051878  0.021576    0.038167  0.107365   0.021559
# jnj_close    0.027679  0.021855  0.012975    0.014665  0.021559   0.018290
# ko_close     0.031052  0.023974  0.015076    0.016690  0.020600   0.012463
# vz_close     0.028771  0.022993  0.014302    0.016049  0.021882   0.012765
# wmt_close    0.019699  0.015331  0.010647    0.012023  0.016052   0.009295
# xom_close    0.050054  0.037533  0.020654    0.026925  0.035936   0.017834
#
#             ko_close  vz_close  wmt_close  xom_close
# bhp_close   0.031052  0.028771   0.019699   0.050054
# de_close    0.023974  0.022993   0.015331   0.037533
# fe_close    0.015076  0.014302   0.010647   0.020654
# goog_close  0.016690  0.016049   0.012023   0.026925
# gs_close    0.020600  0.021882   0.016052   0.035936
# jnj_close   0.012463  0.012765   0.009295   0.017834
# ko_close    0.023919  0.013721   0.010942   0.020103
# vz_close    0.013721  0.027871   0.011232   0.018261
# wmt_close   0.010942  0.011232   0.024244   0.013473
# xom_close   0.020103  0.018261   0.013473   0.039049

# %%
rets.mean() * 252
# Out:
# bhp_close     0.016703
# de_close      0.187173
# fe_close      0.006974
# goog_close    0.060351
# gs_close     -0.046907
# jnj_close     0.078637
# ko_close      0.114172
# vz_close      0.159529
# wmt_close     0.103090
# xom_close     0.117074
# dtype: float64

# %%
data.head()
# Out:
#             bhp_close   de_close   fe_close  goog_close    gs_close  \
# Date
# 2010-01-04  61.755304  47.140779  32.413423  313.062468  157.438422
# 2010-01-05  61.763067  46.964187  32.053043  311.683844  160.221881
# 2010-01-06  62.779773  46.838054  32.399562  303.826685  158.511776
# 2010-01-07  62.228734  47.174412  31.914434  296.753749  161.613611
# 2010-01-08  63.082457  48.460989  31.748107  300.709808  158.557260
#
#             jnj_close   ko_close   vz_close  wmt_close  xom_close
# Date
# 2010-01-04  51.509368  22.920968  21.678162  45.002689  56.187171
# 2010-01-05  50.912089  22.643697  21.717245  44.554570  56.406554
# 2010-01-06  51.326200  22.635661  21.092790  44.454989  56.894077
# 2010-01-07  50.959872  22.579403  20.967238  44.479883  56.715323
# 2010-01-08  51.135072  22.161490  20.980454  44.255827  56.487807

# %%
rets.head()
# Out:
#             bhp_close  de_close  fe_close  goog_close  gs_close  jnj_close  \
# Date
# 2010-01-04        NaN       NaN       NaN         NaN       NaN        NaN
# 2010-01-05   0.000126 -0.003753 -0.011181   -0.004413  0.017525  -0.011663
# 2010-01-06   0.016327 -0.002689  0.010753   -0.025532 -0.010731   0.008101
# 2010-01-07  -0.008816  0.007156 -0.015087   -0.023555  0.019379  -0.007163
# 2010-01-08   0.013626  0.026907 -0.005225    0.013243 -0.019093   0.003432
#
#             ko_close  vz_close  wmt_close  xom_close
# Date
# 2010-01-04       NaN       NaN        NaN        NaN
# 2010-01-05 -0.012171  0.001801  -0.010008   0.003897
# 2010-01-06 -0.000355 -0.029175  -0.002238   0.008606
# 2010-01-07 -0.002488 -0.005970   0.000560  -0.003147
# 2010-01-08 -0.018682  0.000630  -0.005050  -0.004020

# %% [markdown]
# # a Monte Carlo simulation to generate random portfolio weight vectors on a larger scale

# %%
#a Monte Carlo simulation to generate random portfolio weight vectors on a larger scale

prets = []
pvols = []
for p in range (5000):
    weights = np.random.random(noa)
    weights /= np.sum(weights)
    prets.append(np.sum(rets.mean() * weights) * 252)
    pvols.append(np.sqrt(np.dot(weights.T,
    np.dot(rets.cov() * 252, weights))))
prets = np.array(prets)
pvols = np.array(pvols)

## Graphical results of the Monte Carlo simulation
plt.figure(figsize=(8, 4))
plt.scatter(pvols, prets, c=prets / pvols, marker='o')
plt.grid(True)
plt.xlabel('expected volatility')
plt.ylabel('expected return')
plt.colorbar(label='Sharpe ratio')

# %% [markdown]
# # max sharp ration portfolio & weights

# %%
def statistics(weights):

    weights = np.array(weights)
    pret = np.sum(rets.mean() * weights) * 252
    pvol = np.sqrt(np.dot(weights.T, np.dot(rets.cov() * 252, weights)))
    return np.array([pret, pvol, pret / pvol])

import scipy.optimize as sco

def min_func_sharpe(weights):
    return -statistics(weights)[2]

cons = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})

bnds = tuple((0.02, 0.3) for x in range(noa))

noa * [1. / noa,]

# %time
opts = sco.minimize(min_func_sharpe, noa * [1. / noa,], method='SLSQP',
                    bounds=bnds, constraints=cons)
opts
# Out:
# Wall time: 0 ns
#      fun: -0.89676744961354926
#      jac: array([ 1.50430622, -0.01668192,  0.69766165,  0.49322462,  1.59690645,
#         0.06475649, -0.01695149, -0.2680015 , -0.01582602,  0.13877051,  0.        ])
#  message: 'Optimization terminated successfully.'
#     nfev: 84
#      nit: 7
#     njev: 7
#   status: 0
#  success: True
#        x: array([ 0.02      ,  0.07346827,  0.02      ,  0.02      ,  0.02      ,
#         0.02      ,  0.23998856,  0.3       ,  0.26654316,  0.02      ])

# %%
#weights
opts['x'].round(3)
# Out:
# array([ 0.02 ,  0.073,  0.02 ,  0.02 ,  0.02 ,  0.02 ,  0.24 ,  0.3  ,
#         0.267,  0.02 ])

# %%
statistics(opts['x']).round(3)
# Out:
# array([ 0.121,  0.135,  0.897])

# %% [markdown]
# # minimize variance portfolio & weights

# %%
def min_func_variance(weights):
    return statistics(weights)[1] ** 2

optv = sco.minimize(min_func_variance, noa * [1. / noa,],
                    method='SLSQP', bounds=bnds,
                    constraints=cons)

optv

optv['x'].round(3)

statistics(optv['x']).round(3)
# Out:
# array([ 0.096,  0.124,  0.774])

# %% [markdown]
# # Efficient Frontier

# %%
##Efficient Frontier

cons = ({'type': 'eq', 'fun': lambda x: statistics(x)[0] - tret},
         {'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
bnds = tuple((0.02,0.3) for x in weights)

def min_func_port(weights):
    return statistics(weights)[1]


# %time
trets = np.linspace(0.05, 0.14, 50)
tvols = []
for tret in trets:
    cons = ({'type': 'eq', 'fun': lambda x: statistics(x)[0] - tret},
             {'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
    res = sco.minimize(min_func_port, noa * [1. / noa,], method='SLSQP',
                       bounds=bnds, constraints=cons)
    tvols.append(res['fun'])
tvols = np.array(tvols)
# Out:
# Wall time: 0 ns

# %%
plt.figure(figsize=(8, 4))
plt.scatter(pvols, prets,
c=prets / pvols, marker='o')
# random portfolio composition
plt.scatter(tvols, trets,
            c=trets / tvols, marker='x')
# efficient frontier

plt.plot(statistics(opts['x'])[1], statistics(opts['x'])[0],
         'r*', markersize=15.0)
# portfolio with highest Sharpe ratio
plt.plot(statistics(optv['x'])[1], statistics(optv['x'])[0],
         'y*', markersize=15.0)
# minimum variance portfolio
plt.grid(True)
plt.xlabel('expected volatility')
plt.ylabel('expected return')
plt.colorbar(label='Sharpe ratio')

# %% [markdown]
# # get F-F_Research_Data_Factors_daily from web

# %%
import pandas_datareader.data as web
ff = web.DataReader("F-F_Research_Data_Factors_daily", "famafrench",start, end)
ff = pd.DataFrame(ff[0])
ff.head()
# Out:
#             Mkt-RF   SMB   HML   RF
# Date
# 2010-01-04    1.69  0.58  1.12  0.0
# 2010-01-05    0.31 -0.59  1.21  0.0
# 2010-01-06    0.13 -0.25  0.51  0.0
# 2010-01-07    0.40  0.08  0.93  0.0
# 2010-01-08    0.33  0.40  0.01  0.0

# %% [markdown]
# # use max sharp ratio weights as portfolio weights

# %%
weights = opts['x']
weights
# Out:
# array([ 0.04      ,  0.06199378,  0.04      ,  0.04      ,  0.04      ,
#         0.04      ,  0.1727179 ,  0.3       ,  0.22528832,  0.04      ])

# %%
rets.head()
# Out:
#             bhp_close  de_close  fe_close  goog_close  gs_close  jnj_close  \
# Date
# 2010-01-04        NaN       NaN       NaN         NaN       NaN        NaN
# 2010-01-05   0.000126 -0.003753 -0.011181   -0.004413  0.017525  -0.011663
# 2010-01-06   0.016327 -0.002689  0.010753   -0.025532 -0.010731   0.008101
# 2010-01-07  -0.008816  0.007156 -0.015087   -0.023555  0.019379  -0.007163
# 2010-01-08   0.013626  0.026907 -0.005225    0.013243 -0.019093   0.003432
#
#             ko_close  vz_close  wmt_close  xom_close
# Date
# 2010-01-04       NaN       NaN        NaN        NaN
# 2010-01-05 -0.012171  0.001801  -0.010008   0.003897
# 2010-01-06 -0.000355 -0.029175  -0.002238   0.008606
# 2010-01-07 -0.002488 -0.005970   0.000560  -0.003147
# 2010-01-08 -0.018682  0.000630  -0.005050  -0.004020

# %%
potret = pd.DataFrame((rets * weights).sum(1),columns=['portfolio return'])
potret.head()
# Out:
#             portfolio return
# Date
# 2010-01-04          0.000000
# 2010-01-05         -0.004277
# 2010-01-06         -0.009184
# 2010-01-07         -0.003187
# 2010-01-08         -0.002429

# %%
import statsmodels.api as sm

def reg(y,X):
    X = sm.add_constant(X)
    res = sm.OLS(y, X, missing='drop').fit()

    #print(res.summary())
    #print np.std(res.resid)
    
    return res
X = np.array([ff['Mkt-RF'],ff['SMB'],ff['HML']]).T            
print reg(potret['portfolio return']-ff['RF'],X).summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.801
# Model:                            OLS   Adj. R-squared:                  0.800
# Method:                 Least Squares   F-statistic:                     1027.
# Date:                Thu, 20 Apr 2017   Prob (F-statistic):          5.08e-268
# Time:                        20:30:02   Log-Likelihood:                 3179.8
# No. Observations:                 771   AIC:                            -6352.
# Df Residuals:                     767   BIC:                            -6333.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         -0.0002      0.000     -1.559      0.119        -0.000  5.72e-05
# x1             0.0071      0.000     45.840      0.000         0.007     0.007
# x2            -0.0025      0.000     -8.294      0.000        -0.003    -0.002
# x3            -0.0001      0.000     -0.349      0.727        -0.001     0.001
# ==============================================================================
# Omnibus:                       20.279   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.737
# Skew:                          -0.143   Prob(JB):                     6.39e-09
# Kurtosis:                       4.045   Cond. No.                         3.16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # some notes
# ## 1.the portfolio is well diversified because they are from different sectors:

# %%
data = {
'Energy':'Exxon Mobil',
'Financials':'Goldman Sachs',
'Materials':'BHP Billiton ',
'Industrials':'Deere & Company ',
'Utilities':'FirstEnergy Corp.',
'Information Technology':'Google Inc.',
'Telecommunication Services':'Verizon Communications Inc.',
'Consumer Discretionary':'Wal-Mart Stores Inc.',
'Consumer Staples':'Coca-Cola Company',
'Health Care':'Johnson & Johnson',
}
pd.DataFrame(data.values(),index=data.keys(),columns=['companies'])
# Out:
#                                               companies
# Industrials                            Deere & Company
# Consumer Discretionary             Wal-Mart Stores Inc.
# Health Care                           Johnson & Johnson
# Materials                                 BHP Billiton
# Consumer Staples                      Coca-Cola Company
# Information Technology                      Google Inc.
# Telecommunication Services  Verizon Communications Inc.
# Energy                                      Exxon Mobil
# Utilities                             FirstEnergy Corp.
# Financials                                Goldman Sachs

# %% [markdown]
# ## 2. the Estimated  factor betas using the Fama French 3 factor model are:
# ### alpha:                   -0.0002
# ### beta(im)                0.0071
# ### beta(SMB)            -0.0025
# ### beta(HML)            -0.0001
