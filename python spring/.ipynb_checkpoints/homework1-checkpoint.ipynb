# %%
#get data from web

import urllib
import datetime
import numpy as np
import pandas as pd

### get the url for the downloadable csv-file data
def make_url(ticker_symbol, start_date, end_date):
    base_url = "http://ichart.finance.yahoo.com/table.csv?s="
    # print ticker_symbol
    a = start_date
    b = end_date
    dt_url = '%s&a=%d&b=%d&c=%d&d=%d&e=%d&f=%d&g=d&ignore=.csv'% (ticker_symbol, a.month-1, a.day, a.year, b.month-1, b.day,b.year)
    return base_url + dt_url

### create a path to save the file downloaded from web
#mac
#output_path = "/Users/apple/Downloads/lecture4" ## <======Please change to your own directory
#win
output_path = "C:/Users/bjd/Desktop/data" ## <======Please change to your own directory


def make_filename(ticker_symbol):
    return output_path + "/" + ticker_symbol + ".csv"
    

### pull the data out from web and store the file in the path that designed above
def pull_historical_data(ticker_symbol, start_date, end_date):
    try:
        urllib.urlretrieve(make_url(ticker_symbol, start_date, end_date), make_filename(ticker_symbol))
    except urllib.ContentTooShortError as e:
        outfile = open(make_filename(ticker_symbol), "w")
        outfile.write(e.content)
        outfile.close()

# %%
#changing directory

import os
#mac
#os.chdir( "/Users/apple/Downloads/lecture4/")
#win
os.chdir( "C:/Users/bjd/Desktop/data") 



#symbols = ['VNET','AAPL','HPQ','AMD','MSFT','GOOG','T','COST','A','LB','RAD','NVGN','SCON','MMM','STZ','SUN','JAZZ','GE','GM','SNE']
#symbols = ['VNET','AAPL','HPQ','AMD','MSFT','GOOG','T']
symbols = ['VNET','AAPL']

start = datetime.date(2012,1,1)
end = datetime.date(2013,1,1)
rf = 0

#for passive equity portfolio:
ErM = 0.16
SigmaRM  = 0.23


#portfolio data
for symbol in symbols:
    pull_historical_data(symbol,start,end) ###<=== get historical time-series data for  HPQ
    np.genfromtxt('%s.csv' %symbol, delimiter=",", skip_header=1)

# %%
data = dict()
for symbol in symbols:
    # create a new array in this slot
    data[symbol] = pd.read_csv('%s.csv' %symbol, sep=',', na_values=".")

#print data['AAPL']

#market data
pull_historical_data('SPY',start,end) ###<=== get historical time-series data for  HPQ
np.genfromtxt('SPY.csv', delimiter=",", skip_header=1) 
SPY = pd.read_csv('SPY.csv', sep=',', na_values=".")
SPY
# Out:
#            Date        Open        High         Low       Close     Volume  \
# 0    2012-12-31  139.660004  142.559998  139.539993  142.410004  243935200
# 1    2012-12-28  140.639999  141.419998  139.869995  140.029999  148806700
# 2    2012-12-27  141.789993  142.080002  139.919998  141.559998  167920600
# 3    2012-12-26  142.639999  142.710007  141.350006  141.750000  106947700
# 4    2012-12-24  142.479996  142.559998  142.190002  142.350006   53874600
# 5    2012-12-21  142.169998  144.089996  141.940002  142.789993  245883800
# 6    2012-12-20  144.380005  145.139999  143.979996  145.119995  168487000
# 7    2012-12-19  145.529999  145.580002  144.240005  144.289993  150895400
# 8    2012-12-18  144.000000  145.500000  143.789993  145.369995  177762800
# 9    2012-12-17  142.470001  143.850006  142.429993  143.770004  143238200
# 10   2012-12-14  142.320007  142.580002  141.880005  142.100006  137701700
# 11   2012-12-13  143.419998  143.830002  142.270004  142.630005  135715000
# 12   2012-12-12  144.000000  144.550003  143.309998  143.509995  145880100
# 13   2012-12-11  143.059998  144.110001  142.990005  143.440002  152570400
# 249  2012-01-03  127.760002  128.380005  127.430000  127.500000  193697900
#
#       Adj Close
# 0    130.758644
# 1    128.573360
# 2    129.978181
# 3    130.152639
# 4    130.703555
# 5    131.107544
# 6    132.308531
# 7    131.551803
# 8    132.536460
# 9    131.077719
# 10   129.555152
# 11   130.038361
# 12   130.840664
# 13   130.776851
# 14   129.892483
# 15   129.837782
# 16   129.445736
# 17   129.008115
# 18   128.780186
# 19   128.962527
# 20   129.600727
# 21   129.573376
# 22   128.971653
# 23   127.941407
# 24   128.597845
# 25   128.871363
# 26   127.139090
# 27   126.902049
# 28   126.847348
# 29   124.330997
# ..          ...
# 220  121.436561
# 221  121.589264
# 222  120.690999
# 223  121.589264
# 224  121.436561
# 225  121.077246
# 226  120.771839
# 227  120.852680
# 228  119.181905
# 229  118.993277
# 230  117.960277
# 231  118.005179
# 232  118.409409
# 233  118.463303
# 234  119.074117
# 235  118.086033
# 236  118.220768
# 237  118.526175
# 238  118.086033
# 239  117.466228
# 240  116.181700
# 241  115.732567
# 242  116.334404
# 243  116.055944
# 244  115.993072
# 245  114.995996
# 246  114.717529
# 247  115.013952
# 248  114.708545
# 249  114.528894
#
# [250 rows x 7 columns]

# %%
#Converting to returns
# assume rf = 0, in practice, rate of return on bills is on the order of only about .01% per day,  so total and excess returns are almost indistinguishable. 

def returns(data):
        data['excess_return'] = np.log(data['Adj Close']/data['Adj Close'].shift(1))-rf

returns(SPY)

for i in data:
    returns(data[i])

data['VNET']
# Out:
#            Date   Open   High    Low  Close  Volume  Adj Close  excess_return
# 0    2012-12-31   8.94   9.97   8.92   9.61  686900       9.61            NaN
# 1    2012-12-28   9.04   9.07   8.86   8.86  132300       8.86      -0.081257
# 2    2012-12-27   8.97   9.00   8.71   9.00  172000       9.00       0.015678
# 3    2012-12-26   8.92   9.01   8.80   8.85  205400       8.85      -0.016807
# 4    2012-12-24   9.24   9.24   8.69   8.83  103000       8.83      -0.002262
# 5    2012-12-21   9.24   9.30   8.76   9.23  588600       9.23       0.044304
# 6    2012-12-20   9.49   9.49   9.12   9.27  202500       9.27       0.004324
# 7    2012-12-19   9.04   9.56   8.98   9.38  465000       9.38       0.011796
# 8    2012-12-18   8.90   9.00   8.80   9.00  161700       9.00      -0.041355
# 9    2012-12-17   8.79   8.92   8.63   8.85  260800       8.85      -0.016807
# 10   2012-12-14   8.70   9.10   8.39   8.62  768800       8.62      -0.026332
# 11   2012-12-13   9.13   9.24   8.70   8.73  185500       8.73       0.012680
# 12   2012-12-12   9.49   9.49   9.00   9.18  209900       9.18       0.050262
# 13   2012-12-11   8.87   9.11   8.80   8.95  193600       8.95      -0.025374
# 14   2012-12-10   8.91   9.00   8.70   8.87  274300       8.87      -0.008979
# 15   2012-12-07   9.04   9.09   8.81   8.91  215000       8.91       0.004499
# 16   2012-12-06   9.19   9.26   8.80   9.05  240500       9.05       0.015591
# 17   2012-12-05   9.27   9.30   9.00   9.12  358000       9.12       0.007705
# 18   2012-12-04   9.54   9.56   9.04   9.33  251100       9.33       0.022765
# 19   2012-12-03   9.77   9.85   9.27   9.58  536000       9.58       0.026443
# 20   2012-11-30   9.79   9.85   9.66   9.77  141900       9.77       0.019639
import statsmodels.api as sm

def reg(y,X):
    X = sm.add_constant(X)
    res = sm.OLS(y, X, missing='drop').fit()

    #print(res.summary())
    #print np.std(res.resid)
    alpha,beta = res.params
    return (alpha,beta, np.std(res.resid))
            
print reg(data['AAPL']['excess_return'],SPY['excess_return'])
a,b,c = reg(data['AAPL']['excess_return'],SPY['excess_return'])
# Out:
# (-0.00040937802043572105, 1.2428983255736568, 0.015560045174479252)

# %%
#loop all stocks

# %%
result = np.empty( shape=(0, 3))
for i in data:
    reg(data[i]['excess_return'],SPY['excess_return'])
    #print i
    #print reg(data[i]['excess_return'],SPY['excess_return'])
    result = np.r_[result,[reg(data[i]['excess_return'],SPY['excess_return'])]]

data1 = pd.DataFrame(result,columns=['alpha','beta','sigma(firm-specific)'],index=data.keys())
data1
# Out:
#          alpha      beta  sigma(firm-specific)
# AAPL -0.000409  1.242898              0.015560
# VNET  0.000421  1.013451              0.030682

# %%
data2 = pd.DataFrame(data1['alpha']/data1['sigma(firm-specific)']**2,columns=['alpha/var'])
data2['weights'] = data2['alpha/var']/np.sum(data2['alpha/var'])
data2.loc['Total'] = data2.sum(numeric_only=True)
data2
# Out:
#        alpha/var   weights
# AAPL   -1.690841  1.359171
# VNET    0.446817 -0.359171
# Total  -1.244024  1.000000

# %%
# Hence the alpha and beta of the active portfolio are 
alpha_p = np.dot(data2['weights'][:-1],data1['alpha'])
beta_p = np.dot(data2['weights'][:-1],data1['beta'])
#Residual variances are
var_residual_p =  np.dot(data2['weights'][:-1]**2,data1['sigma(firm-specific)']**2)
std_residual_p = np.sqrt(var_residual_p)
std_residual_p
# Out:
# 0.023847771929550336

# %%
#adjusted weight for beta
w0 = (alpha_p/var_residual_p)/((ErM -rf)/(SigmaRM**2))

w_star = w0/(1+(1-beta_p)*w0)
w_star
# Out:
# -0.36276667306107452

# %%
#Position in the index portfolio is 
weight_index = 1- (w_star)
weight_index
# Out:
# 1.3627666730610746

# %%
# To calculate the Sharpe ratio for the optimal risky portfolio, 
# we compute the information ratio for the active portfolio and Sharpe’s measure for the market portfolio. 
# The information ratio for the active portfolio is computed as follows 

A = alpha_p/std_residual_p
A**2
# Out:
# 0.00088014257138012766

# %%
# Hence, the square of the Sharpe ratio (S) of the optimized risky portfolio is: 
S_sq = ( (ErM-rf)/SigmaRM  )**2 + A**2
S = np.sqrt(S_sq)
S
# Out:
# 0.6962844890138824

# %%
market_S = (ErM-rf)/SigmaRM  
market_S
# Out:
# 0.6956521739130435

# %%
# To calculate the makeup of the complete portfolio, first compute the beta, the mean excess return, 
# and the variance of the optimal risky portfolio: 

beta_cp = weight_index + ( w_star*beta_p)
mean_excess_return = w_star*alpha_p+beta_cp*ErM
var_cp = beta_cp**2*SigmaRM**2+w_star**2*var_residual_p
std_cp = np.sqrt(var_cp)
std_cp
# Out:
# 0.20304177362308243

# %%
# with a coefficient of risk aversion of 2.8?     
# the optimal position in this portfolio is
aversion = 2.8
y = mean_excess_return/(0.01*aversion*var_cp*1000)
y
# Out:
# 0.12247382760372144

# %%
# In contrast, with a passive strategy: 

y1 = (ErM-rf)*100/(0.01*aversion*(SigmaRM*100)**2)
y1
# Out:
# 1.0802052389954093
