# %%
import pandas as pd
import numpy as np

volume = pd.read_csv('volume.csv',header =4)

lc = volume.ix[:,0:2]
sc = volume.ix[:,3:5]
spx_v  = volume.ix[:,5:6]
spx_v
# Out:
#             SPX
# 0    1181.27000
# 1    1203.60000
# 2    1180.59000
# 3    1156.85000
# 4    1191.50000
# 5    1191.33000
# 6    1234.18000
# 7    1220.33000
# 8    1228.81000
# 9    1207.01000
# 10   1249.48000
# 11   1248.29000
# 12   1280.08000
# 13   1280.66000
# 14   1294.87000
# 15   1310.61000
# 16   1270.09000
# 17   1270.20000
# 18   1276.66000
# 19   1303.82000
# 20   1335.85000
# 21   1377.94000
# 22   1400.63000
# 23   1418.30000
# 24   1438.24000
# 25   1406.82000
# 26   1420.86000
# 27   1482.37000
# 28   1530.62000
# 29   1503.35000
# ..          ...
# 90   1379.32000
# 91   1406.58000
# 92   1440.67000
# 93   1412.16000
# 94   1416.18000
# 95   1426.19000
# 96   1498.11093
# 97   1514.67827
# 98   1569.18587
# 99   1597.56567
# 100  1630.74189
# 101  1606.27761
# 102  1685.72502
# 103  1632.97115
# 104  1681.54666
# 105  1756.54463
# 106  1805.81269
# 107  1848.35652
# 108  1782.58697
# 109  1859.44937
# 110  1872.33518
# 111  1883.95013
# 112  1923.57266
# ...

# %%
volume
# Out:
#         Month        ADV  Volatility    ADV.1  Volatility.1         SPX
# 0    Jan-2005  4,145,429      0.2306  414,942        0.3705  1181.27000
# 1    Feb-2005  3,934,471      0.2419  400,271        0.3787  1203.60000
# 2    Mar-2005  3,905,479      0.2326  405,187        0.3552  1180.59000
# 3    Apr-2005  4,121,933      0.2808  401,821        0.4279  1156.85000
# 4    May-2005  3,621,475      0.2310  391,428        0.4028  1191.50000
# 5    Jun-2005  3,413,944      0.1986  399,808        0.3539  1191.33000
# 6    Jul-2005  3,561,657      0.2269  382,196        0.3731  1234.18000
# 7    Aug-2005  3,266,285      0.2062  374,321        0.3553  1220.33000
# 8    Sep-2005  3,874,930      0.2337  399,728        0.3521  1228.81000
# 9    Oct-2005  4,351,479      0.3023  424,493        0.4258  1207.01000
# 10   Nov-2005  3,929,000      0.2402  414,693        0.3814  1249.48000
# 11   Dec-2005  3,608,421      0.2044  407,982        0.3321  1248.29000
# ...
