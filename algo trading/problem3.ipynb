# %%
import pandas as pd
import numpy as np

C = pd.read_csv('c.csv',index_col = 0 )


stock_data = pd.read_csv('stock_data.csv',header=2)
stock_data[stock_data['Group']==4]
# Out:
#     Group Symbol   Price       ADV  Volatility  LnMktCap  EstReturn %
# 75      4    CAT   78.63   5224000      0.2017     24.49         0.14
# 76      4     CB  124.33   1223000      0.2069     24.12         0.10
# 77      4    CBG   37.97   2061000      0.2103     23.24         0.14
# 78      4    CBS   53.28   6561000      0.2214     23.90         0.12
# 79      4    CCE   50.80   2210000      0.2038     23.17         0.10
# 80      4    CCI   81.91   2550000      0.1691     24.09         0.08
# 81      4    CCL   52.99   4036000      0.2240     24.43         0.09
# 82      4   CELG  131.25   5468000      0.2824     25.21         0.17
# 83      4   CERN   71.72   1652000      0.2176     23.73         0.14
# 84      4     CF   58.89   3777000      0.2457     23.09         0.12
# 85      4    CHK    8.66  13378000      0.4070     22.02         0.21
# 86      4   CHRW   69.75   1680000      0.2149     23.01         0.15
# 87      4     CI  144.06   1834000      0.2384     24.27         0.14
# 88      4   CINF   55.21    566000      0.1412     23.03         0.06
# 89      4     CL   68.02   3051000      0.1392     24.82         0.07
# 90      4    CLX  111.94   1027000      0.1398     23.51         0.10
# 91      4    CMA   47.43   1617000      0.2155     22.83         0.09
# 92      4  CMCSA   62.41  13844000      0.1829     25.74         0.08
# 93      4    CME   95.52   1635000      0.1867     24.21         0.14
# 94      4    CMG  742.23    463000      0.2700     23.61         0.15
# 95      4    CMI  128.54   1495000      0.2062     23.59         0.10
# 96      4    CMS   33.97   2609000      0.1667     23.00         0.08
# 97      4    CNP   19.09   3888000      0.1839     22.72         0.07
# 98      4    CNX   16.51   2941000      0.3239     21.27         0.14
# 99      4    COF   80.90   2915000      0.1947     24.48         0.14

# %%
C
# Out:
#             CAT        CB       CBG       CBS       CCE       CCI       CCL  \
# CAT    0.040837  0.011485  0.015074  0.017006  0.014289  0.008574  0.014396
# CB     0.011485  0.043000  0.011264  0.012521  0.011038  0.006828  0.011370
# CBG    0.015074  0.011264  0.044410  0.017530  0.014933  0.008940  0.015735
# CBS    0.017006  0.012521  0.017530  0.049189  0.016771  0.009956  0.017689
# CCE    0.014289  0.011038  0.014933  0.016771  0.041703  0.008834  0.015442
# CCI    0.008574  0.006828  0.008940  0.009956  0.008834  0.028737  0.009351
# CCL    0.014396  0.011370  0.015735  0.017689  0.015442  0.009351  0.050374
# CELG   0.016525  0.013796  0.020567  0.023247  0.020428  0.012250  0.023111
# CERN   0.015196  0.011402  0.016765  0.019110  0.016111  0.009477  0.017488
# CF     0.012164  0.009228  0.012484  0.014049  0.012096  0.007306  0.012727
# CHK    0.022022  0.013389  0.017665  0.020364  0.015553  0.008842  0.014184
# CHRW   0.012990  0.009489  0.013424  0.015265  0.012800  0.007561  0.013518
# CI     0.012631  0.009512  0.012909  0.014545  0.012472  0.007513  0.013099
# CINF   0.013027  0.009445  0.012562  0.014174  0.011974  0.007186  0.012240
# CL     0.010013  0.007963  0.010064  0.011145  0.009966  0.006210  0.010380
# CLX    0.006877  0.005586  0.007003  0.007726  0.006992  0.004388  0.007323
# CCE    0.012138  0.012159  0.016609  0.007913  0.010984  0.013920  0.014528
# CCI    0.007269  0.007037  0.009893  0.004986  0.006815  0.008025  0.008580
# CCL    0.012614  0.013467  0.017177  0.007997  0.010933  0.013502  0.014903
# CELG   0.015883  0.020054  0.021375  0.009083  0.011895  0.013864  0.018169
# CERN   0.013410  0.015177  0.018418  0.007713  0.010833  0.015194  0.016191
# CF     0.010206  0.010037  0.014017  0.006633  0.009307  0.012163  0.012333
# CHK    0.015732  0.011049  0.022632  0.010128  0.016231  0.028228  0.021361
# CHRW   0.010955  0.011298  0.015140  0.006641  0.009509  0.013561  0.013448
# CI     0.010568  0.010379  0.014534  0.006829  0.009623  0.012751  0.012815
# CINF   0.010480  0.009474  0.014532  0.006914  0.009975  0.013870  0.012985
# CL     0.008277  0.007422  0.011275  0.005950  0.008161  0.009454  0.009798
# CLX    0.005735  0.005171  0.007779  0.004183  0.005674  0.006290  0.006714
# CMA    0.014073  0.012044  0.020019  0.008487  0.013274  0.022683  0.018579
# CMCSA  0.011800  0.011111  0.016211  0.007902  0.011098  0.014305  0.014276
# CME    0.035016  0.010015  0.014444  0.006729  0.009615  0.013223  0.012832
# CMG    0.010015  0.073253  0.013747  0.005281  0.007408  0.010900  0.012068
# CMI    0.014444  0.013747  0.042640  0.009208  0.013278  0.018759  0.017867
# CMS    0.006729  0.005281  0.009208  0.027936  0.007113  0.008298  0.008065
# CNP    0.009615  0.007408  0.013278  0.007113  0.033946  0.012824  0.011799
# CNX    0.013223  0.010900  0.018759  0.008298  0.012824  0.105445  0.017346
# COF    0.012832  0.012068  0.017867  0.008065  0.011799  0.017346  0.038026
#
# [25 rows x 25 columns]

# %% [markdown]
# # qp solver funtion

# %%
from cvxopt import matrix, solvers


def optimal_port(expected_return):
    
    solvers.options['show_progress'] = False      #disable progress
    

    symbol = list(C.index)
    C_s = C.as_matrix()             #convert to matrix
    
    data = stock_data[stock_data['Symbol'].isin(symbol)]      #select stock data based on symbol
    #print data
    ret_T = np.matrix(data['EstReturn %'])                     #get returns 
    #ret_T
    
    n = len(C_s)
    
    # w'Cw minimization using qp
    
    Q = matrix(C_s)                                         # covariance matrix
    p = matrix(np.full((n, 1), 0.))                         # return matrix, 0 here because returns are specfied outside,here only w'Cw
    G = matrix(np.r_[np.eye(n),-np.eye(n)])                 # inequality equation leftside
    h = matrix(np.r_[np.full((n, 1), 0.25),np.full((n, 1), -0.005)])  # inequality equation rightside
    A = matrix(np.r_[np.full((1, n), 1.0),ret_T] ,(2,n))              # equality equation leftside
    b = matrix([1.0,expected_return],(2,1))                           # equality equation rightside
    
    sol=solvers.qp(Q, p, G, h, A, b)
    
    std =  np.sqrt(np.dot(np.dot(np.array(sol['x']).T,C_s),np.array(sol['x'])))  # std = sqrt(w'Cw)
    returns = np.sum(np.full((n, 1), expected_return)*np.array(sol['x']))        # returns = sumproduct(w,R)
    #print returns
    #print std.shape
    return np.r_[np.array(sol['x']),std,np.array([[returns]])]                  # return w,std,return which is [n+2,1] matrix, n is the len(C)

#expected_return = 0.13
#print expected_return
#optimal_port(expected_return)

# %% [markdown]
# # protfolio with different expected return

# %%
weights = np.zeros([len(C)+2,1])            #initial an empty array
expected_return = [0.165,0.16,0.155,0.15,0.145,0.14,0.135,0.13,0.125,0.12,0.115,0.11,0.105,0.10,0.09,0.08]


for j in expected_return:
    weights = np.c_[weights,optimal_port(j)]
    
weights = np.delete(weights, 0, 1)
weights = pd.DataFrame(weights.T ,columns=['w'+ str(i) for i in xrange(1,len(C)+1)]+['std','ret'],index=['portfolio'+ str(i) for i in xrange(1,len(expected_return)+1)])
weights
# Out:
#                    w1        w2        w3     w4        w5        w6     w7  \
# portfolio1   0.005000  0.005000  0.005000  0.005  0.005000  0.005000  0.005
# portfolio2   0.015351  0.005000  0.007393  0.005  0.005000  0.005000  0.005
# portfolio3   0.042054  0.005000  0.030881  0.005  0.005000  0.005000  0.005
# portfolio4   0.062871  0.005000  0.049588  0.005  0.005000  0.005000  0.005
# portfolio5   0.061564  0.005000  0.048951  0.005  0.005000  0.005000  0.005
# portfolio6   0.059270  0.005000  0.047443  0.005  0.005000  0.005000  0.005
# portfolio7   0.056881  0.005006  0.045850  0.005  0.005000  0.005001  0.005
# portfolio8   0.051032  0.010227  0.041685  0.005  0.005000  0.011348  0.005
# portfolio9   0.044190  0.019872  0.036480  0.005  0.005000  0.037329  0.005
# portfolio10  0.037168  0.030785  0.030521  0.005  0.005000  0.066189  0.005
# portfolio11  0.029170  0.035664  0.023134  0.005  0.005000  0.082325  0.005
# portfolio12  0.020734  0.039461  0.015220  0.005  0.005000  0.096271  0.005
# portfolio13  0.011867  0.042215  0.007492  0.005  0.005001  0.108204  0.005
# portfolio14  0.005002  0.042662  0.005001  0.005  0.005000  0.117974  0.005
# portfolio15  0.005000  0.035663  0.005000  0.005  0.005000  0.127348  0.005
# portfolio16  0.005000  0.005001  0.005000  0.005  0.005000  0.120559  0.005
#
#                    w8        w9       w10  ...         w18       w19  \
# portfolio1   0.250000  0.005000  0.005000  ...    0.005000  0.037577
# portfolio2   0.197247  0.005000  0.005000  ...    0.005000  0.121189
# portfolio3   0.148696  0.005001  0.005000  ...    0.005000  0.145750
# portfolio4   0.102541  0.010882  0.005001  ...    0.005000  0.164441
# portfolio5   0.080248  0.013475  0.005336  ...    0.005000  0.158819
# portfolio6   0.058072  0.015152  0.015336  ...    0.005000  0.152264
# portfolio7   0.035923  0.016720  0.026283  ...    0.005000  0.145619
# portfolio8   0.022175  0.015689  0.030303  ...    0.005000  0.136575
# portfolio9   0.010986  0.013221  0.031737  ...    0.005000  0.126776
# portfolio10  0.005010  0.009516  0.033385  ...    0.005000  0.116615
# portfolio11  0.005001  0.005573  0.032652  ...    0.005000  0.105635
# portfolio12  0.005000  0.005019  0.031407  ...    0.005000  0.094213
# portfolio13  0.005000  0.005008  0.029844  ...    0.005000  0.082776
# portfolio14  0.005000  0.005000  0.026620  ...    0.005000  0.067234
# portfolio15  0.005000  0.005000  0.014932  ...    0.005000  0.025287
# portfolio16  0.005000  0.005000  0.005000  ...    0.005001  0.005000
#
#                   w20    w21       w22       w23       w24       w25  \
# portfolio1   0.134527  0.005  0.005000  0.005000  0.005000  0.005000
# portfolio2   0.118508  0.005  0.005000  0.005000  0.005001  0.005048
# portfolio3   0.113194  0.005  0.005000  0.005000  0.005020  0.029553
# portfolio4   0.106807  0.005  0.005000  0.005000  0.008405  0.054976
# portfolio5   0.099137  0.005  0.005000  0.005000  0.009313  0.055707
# portfolio6   0.091274  0.005  0.005000  0.005000  0.009963  0.055306
# portfolio7   0.083397  0.005  0.005064  0.005000  0.010547  0.054797
# portfolio8   0.077231  0.005  0.036131  0.005000  0.009930  0.050453
# portfolio9   0.071540  0.005  0.060441  0.005000  0.008968  0.044750
# portfolio10  0.065218  0.005  0.088160  0.005000  0.008143  0.038586
# portfolio11  0.059073  0.005  0.103504  0.005000  0.007181  0.030980
# portfolio12  0.052768  0.005  0.116781  0.005019  0.006228  0.022760
# portfolio13  0.046782  0.005  0.127839  0.014543  0.005464  0.014160
# portfolio14  0.039606  0.005  0.136177  0.029507  0.005001  0.005007
# portfolio15  0.021836  0.005  0.142134  0.044396  0.005000  0.005000
# portfolio16  0.005000  0.005  0.133460  0.064867  0.005000  0.005000
#
#                   std    ret
# portfolio1   0.174913  0.165
# portfolio2   0.160046  0.160
# portfolio3   0.147762  0.155
# portfolio4   0.137960  0.150
# portfolio5   0.129819  0.145
# portfolio6   0.122689  0.140
# portfolio7   0.116725  0.135
# portfolio8   0.111836  0.130
# portfolio9   0.107575  0.125
# portfolio10  0.103960  0.120
# portfolio11  0.101013  0.115
# portfolio12  0.098600  0.110
# portfolio13  0.096748  0.105
# portfolio14  0.095444  0.100
# portfolio15  0.094573  0.090
# portfolio16  0.097737  0.080
#
# [16 rows x 27 columns]

# %% [markdown]
# # efficient frontier

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(weights['std'],weights['ret'],'y-o')

# %% [markdown]
# # problem 3.2
# # according to the chart before
# # expected return = 9%
# # std = 0.094573

# %% [markdown]
# # For a  $100 Million Dollar Portfolio

# %%
capital = 100*10**6
w = np.array([weights.loc['portfolio14'][0:25]]).T
price = np.array([stock_data[stock_data['Group']==4]['Price']]).T
shares = w*capital / price

ADV = np.array([stock_data[stock_data['Group']==4]['ADV']],dtype='f8').T
size  = shares / ADV                                                     # size(%ADV) 
time = 1                                                                 # trade time % of day. relation to POV = size*(1-POV)/POV
POV = shares/(shares+time*ADV)                                           #shares/VOL = shares / (shares+time*ADV)
volatility = np.array([stock_data[stock_data['Group']==4]['Volatility']],dtype='f8').T

x = np.array(np.c_[size, volatility, POV])

# %%
coeffs = [698.74940594355189, 0.3429159597976898, 0.55893058943625173, 0.74906715225239062, 0.97462393173698603]     #from problem 2
def MI_model(x):
    "market impact function"
    
    s = np.array(x[0])          #size
    v = np.array(x[1])          #volatility
    P = np.array(x[2])          #POV

    return coeffs[0]*(s**coeffs[1])*(v **coeffs[2]) * (coeffs[4]*(P **coeffs[3])+ (1-coeffs[4]))

MI_model(x[1])
# Out:
# 7.7430276506880436

# %%
mi = []
for i in xrange(len(x)):
    mi.append(MI_model(x[i]))
    
stocks = stock_data[stock_data['Group']==4] 
stocks.loc[:,'market_impact(bp)'] = mi
stocks.loc[:,'market_impact(decimal)'] = np.array(mi)/10000
stocks.loc[:,'market_impact(dollar)'] = np.array([mi]).T/10000*w*capital
stocks.loc[:,'net_return %'] = stocks.loc[:,'EstReturn %']-stocks.loc[:,'market_impact(decimal)']*100
stocks
# Out:
# /Users/apple/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:297: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users
# 84      0.077724
# 85      0.182679
# 86      0.045195
# 87      0.098234
# 88     -0.024935
# 89     -0.062931
# 90     -0.304799
# 91      0.064821
# 92      0.073909
# 93      0.033147
# 94      0.106712
# 95      0.086236
# 96     -0.244997
# 97     -0.028628
# 98      0.096002
# 99      0.128107

# %%
# expected Net Return
e_n_return  = np.sum(stocks.loc[:,'net_return %'])/100
e_n_return
# Out:
# 0.010957188658605552

# %% [markdown]
# # For a $500 Million Dollar Portfolio:

# %%
capital = 500*10**6
w = np.array([weights.loc['portfolio14'][0:25]]).T
price = np.array([stock_data[stock_data['Group']==4]['Price']]).T
shares = w*capital / price

ADV = np.array([stock_data[stock_data['Group']==4]['ADV']],dtype='f8').T
size  = shares / ADV                                                     # size(%ADV) 
time = 1                                                                 # trade time % of day. relation to POV = size*(1-POV)/POV
POV = shares/(shares+time*ADV)                                           #shares/VOL = shares / (shares+time*ADV)
volatility = np.array([stock_data[stock_data['Group']==4]['Volatility']],dtype='f8').T

x = np.array(np.c_[size, volatility, POV])
mi = []

for i in xrange(len(x)):
    mi.append(MI_model(x[i]))
    
stocks = stock_data[stock_data['Group']==4] 
stocks.loc[:,'market_impact(bp)'] = mi
stocks.loc[:,'market_impact(decimal)'] = np.array(mi)/10000

stocks.loc[:,'market_impact(dollar)'] = np.array([mi]).T/10000*w*capital
stocks.loc[:,'net_return %'] = stocks.loc[:,'EstReturn %']-stocks.loc[:,'market_impact(decimal)']*100
stocks
#size
# Out:
#     Group Symbol   Price       ADV  Volatility  LnMktCap  EstReturn %  \
# 75      4    CAT   78.63   5224000      0.2017     24.49         0.14
# 76      4     CB  124.33   1223000      0.2069     24.12         0.10
# 77      4    CBG   37.97   2061000      0.2103     23.24         0.14
# 78      4    CBS   53.28   6561000      0.2214     23.90         0.12
# 79      4    CCE   50.80   2210000      0.2038     23.17         0.10
# 80      4    CCI   81.91   2550000      0.1691     24.09         0.08
# 81      4    CCL   52.99   4036000      0.2240     24.43         0.09
# 82      4   CELG  131.25   5468000      0.2824     25.21         0.17
# 83      4   CERN   71.72   1652000      0.2176     23.73         0.14
# 84      4     CF   58.89   3777000      0.2457     23.09         0.12
# 85      4    CHK    8.66  13378000      0.4070     22.02         0.21
# 86      4   CHRW   69.75   1680000      0.2149     23.01         0.15
# 87      4     CI  144.06   1834000      0.2384     24.27         0.14
# 88      4   CINF   55.21    566000      0.1412     23.03         0.06
# 89      4     CL   68.02   3051000      0.1392     24.82         0.07
# 90      4    CLX  111.94   1027000      0.1398     23.51         0.10
# 91      4    CMA   47.43   1617000      0.2155     22.83         0.09
# 92      4  CMCSA   62.41  13844000      0.1829     25.74         0.08
# 93      4    CME   95.52   1635000      0.1867     24.21         0.14
# 94      4    CMG  742.23    463000      0.2700     23.61         0.15
# 95      4    CMI  128.54   1495000      0.2062     23.59         0.10
# 96      4    CMS   33.97   2609000      0.1667     23.00         0.08
# 97      4    CNP   19.09   3888000      0.1839     22.72         0.07
# 98      4    CNX   16.51   2941000      0.3239     21.27         0.14
# 99      4    COF   80.90   2915000      0.1947     24.48         0.14
#
#     market_impact(bp)  market_impact(decimal)  market_impact(dollar)  \
# 75           2.315225                0.000232           5.790463e+02
# 76          33.709269                0.003371           7.190568e+04
# 77           8.754135                0.000875           2.188844e+03
# 78           2.726772                0.000273           6.816936e+02
# 79           6.298161                0.000630           1.574547e+03
# 80          56.881708                0.005688           3.355291e+05
# 81           3.942386                0.000394           9.855974e+02
# 82           1.949294                0.000195           4.873237e+02
# 83           6.243147                0.000624           1.560804e+03
# 84          16.821986                0.001682           2.239037e+04
# 85           9.028001                0.000903           2.257033e+03
# 86          46.189185                0.004619           1.044714e+05
# 87          16.634208                0.001663           2.646051e+04
# 88          37.448676                0.003745           2.321498e+04
# 89          58.024058                0.005802           3.938626e+05
# 90         149.249228                0.014925           1.865615e+06
# 91           9.032347                0.000903           2.258090e+03
# 92           1.368785                0.000137           3.421970e+02
# 93          47.145925                0.004715           1.584905e+05
# 94          17.127945                0.001713           3.391840e+04
# 95           4.090092                0.000409           1.022524e+03
# 96         128.361916                0.012836           8.739972e+05
# 97          43.487220                0.004349           6.415907e+04
# 98          17.106867                0.001711           4.277621e+03
# 99           3.387098                0.000339           8.480312e+02
#
#     net_return %
# 75      0.116848
# 76     -0.237093
# 77      0.052459
# 78      0.092732
# 79      0.037018
# 80     -0.488817
# 81      0.050576
# 82      0.150507
# 83      0.077569
# 84     -0.048220
# 85      0.119720
# 86     -0.311892
# 87     -0.026342
# 88     -0.314487
# 89     -0.510241
# 90     -1.392492
# 91     -0.000323
# 92      0.066312
# 93     -0.331459
# 94     -0.021279
# 95      0.059099
# 96     -1.203619
# 97     -0.364872
# 98     -0.031069
# 99      0.106129

# %%
e_n_return  = np.sum(stocks.loc[:,'net_return %'])/100
e_n_return
# Out:
# -0.043532363286880392

# %%
#stocks.to_csv('100M.csv')

# %% [markdown]
# # problem 3.3

# %% [markdown]
# # 100M

# %%
stocks = stock_data[stock_data['Group']==4] 
returns = np.array(stocks['EstReturn %'])
returns = returns.reshape(len(returns),1)
returns
# Out:
# array([[ 0.14],
#        [ 0.1 ],
#        [ 0.14],
#        [ 0.12],
#        [ 0.1 ],
#        [ 0.08],
#        [ 0.09],
#        [ 0.17],
#        [ 0.14],
#        [ 0.12],
#        [ 0.21],
#        [ 0.15],
#        [ 0.14],
#        [ 0.06],
#        [ 0.07],
#        [ 0.1 ],
#        [ 0.09],
#        [ 0.08],
#        [ 0.14],
#        [ 0.15],
#        [ 0.1 ],
#        [ 0.08],
#        [ 0.07],
#        [ 0.14],
#        [ 0.14]])

# %%
weights
# Out:
#                    w1        w2        w3     w4        w5        w6     w7  \
# portfolio1   0.005000  0.005000  0.005000  0.005  0.005000  0.005000  0.005
# portfolio2   0.015351  0.005000  0.007393  0.005  0.005000  0.005000  0.005
# portfolio3   0.042054  0.005000  0.030881  0.005  0.005000  0.005000  0.005
# portfolio4   0.062871  0.005000  0.049588  0.005  0.005000  0.005000  0.005
# portfolio5   0.061564  0.005000  0.048951  0.005  0.005000  0.005000  0.005
# portfolio6   0.059270  0.005000  0.047443  0.005  0.005000  0.005000  0.005
#
#                   std    ret
# portfolio1   0.174913  0.165
# portfolio2   0.160046  0.160
# portfolio3   0.147762  0.155
# portfolio4   0.137960  0.150
# portfolio5   0.129819  0.145
# portfolio6   0.122689  0.140
# portfolio7   0.116725  0.135
# portfolio8   0.111836  0.130
# portfolio9   0.107575  0.125
# portfolio10  0.103960  0.120
# portfolio11  0.101013  0.115
# portfolio12  0.098600  0.110
# portfolio13  0.096748  0.105
# portfolio14  0.095444  0.100
# portfolio15  0.094573  0.090
# portfolio16  0.097737  0.080
#
# [16 rows x 27 columns]

# %%
w = np.array([weights.loc['portfolio14'][0:25]]).T

# %%
def mi(weights,capital):
    w = weights
    price = np.array([stock_data[stock_data['Group']==4]['Price']]).T
    shares = w*capital / price

    ADV = np.array([stock_data[stock_data['Group']==4]['ADV']],dtype='f8').T
    size  = shares / ADV                                                     # size(%ADV) 
    time = 1                                                                 # trade time % of day. relation to POV = size*(1-POV)/POV
    POV = shares/(shares+time*ADV)                                           #shares/VOL = shares / (shares+time*ADV)
    volatility = np.array([stock_data[stock_data['Group']==4]['Volatility']],dtype='f8').T

    x = np.array(np.c_[size, volatility, POV])
    market_impact = []
    for i in xrange(len(x)):
        market_impact = np.append(market_impact,MI_model(x[i,:]))
    #print market_impact  
    market_impact = market_impact.reshape(len(market_impact),1)
    
    return np.array(market_impact)

# %%
capital = 100*10**6

mi(w,capital)
# Out:
# array([[  0.90828192],
#        [  7.74302765],
#        [  2.44970269],
#        [  1.03713021],
#        [  1.89370213],
#        [ 12.94586905],
#        [  1.35678242],
#        [  0.84303534],
#        [  1.8981089 ],
#        [  4.22757794],
#        [  2.73210796],
#        [ 10.48054036],
#        [  4.17661564],
#        [  8.49354867],
#        [ 13.29314908],
#        [ 40.47986832],
#        [  2.51792583],
#        [  0.60909609],
#        [ 10.68528841],
#        [  4.32879275],
#        [  1.37635179],
#        [ 32.49970774],
#        [  9.86284356],
#        [  4.39975137],
#        [  1.18930758]])

# %%
variance = 0.033922

# %%
def func(w):
     """ Objective function """
     return np.sum(w*mi(w,capital)-w*returns)

# %%
cons = ({'type': 'eq',
          'fun' : lambda w: np.array([np.sum(w) -1])},
        
        {'type': 'eq',
          'fun' : lambda w: np.array([np.dot(np.dot(w.T,C),w) - variance])}

       )

# %%
res = minimize(func, w,
                constraints=cons, method='SLSQP',bounds=np.full((25,2),(0.005,0.25)), options={'disp': True})
print(res.x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-fc896f57594e> in <module>()
# ----> 1 res = minimize(func, w,
#       2                 constraints=cons, method='SLSQP',bounds=np.full((25,2),(0.005,0.25)), options={'disp': True})
#       3 print(res.x)
#
# NameError: name 'minimize' is not defined

# %%
new_w = np.reshape(res.x,(len(res.x),1))
new_w

# %%
func(res.x)

# %%
func(w)

# %% [markdown]
# # 500M

# %%
capital = 500*10**6

mi(w,capital)

# %%
variance = 0.033922
res = minimize(func, w,
                constraints=cons, method='SLSQP',bounds=np.full((25,2),(0.005,0.25)), options={'disp': True})
print(res.x)

# %%
new_w = np.reshape(res.x,(len(res.x),1))
new_w

# %%
func(res.x)

# %%
func(w)
